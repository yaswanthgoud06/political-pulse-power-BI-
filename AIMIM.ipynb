# %%
pip install --upgrade pip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ntscraper import Nitter

# %%
scraper = Nitter(log_level = 1,skip_instance_check= False)
# Out:
# Testing instances: 100%|███████████████████████████████████████████████████████████████| 77/77 [02:33<00:00,  1.99s/it]

# %%
tweets = scraper.get_tweets('aimim_national',mode= 'user', number=850)
# Out:
# 04-Apr-24 14:49:29 - No instance specified, using random instance https://nitter.privacydev.net
# 04-Apr-24 14:49:35 - Current stats for aimim_national: 21 tweets, 0 threads...
# 04-Apr-24 14:49:39 - Current stats for aimim_national: 41 tweets, 0 threads...
# 04-Apr-24 14:49:43 - Current stats for aimim_national: 61 tweets, 0 threads...
# 04-Apr-24 14:49:47 - Current stats for aimim_national: 81 tweets, 0 threads...
# 04-Apr-24 14:49:51 - Current stats for aimim_national: 101 tweets, 0 threads...
# 04-Apr-24 14:49:56 - Current stats for aimim_national: 121 tweets, 0 threads...
# 04-Apr-24 14:50:02 - Current stats for aimim_national: 141 tweets, 0 threads...
# 04-Apr-24 14:50:07 - Current stats for aimim_national: 161 tweets, 0 threads...
# 04-Apr-24 14:50:12 - Current stats for aimim_national: 181 tweets, 0 threads...
# 04-Apr-24 14:50:17 - Current stats for aimim_national: 201 tweets, 0 threads...
# 04-Apr-24 14:50:19 - Empty page on https://nitter.privacydev.net

# %%
from pprint import pprint

# %%
pprint(tweets)
# Out:
# {'threads': [],
#  'tweets': [{'date': 'Mar 12, 2024 · 12:11 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': True,
#              'is-retweet': False,
#              'link': 'https://twitter.com/aimim_national/status/1767523795814985760#m',
#              'pictures': [],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 30,
#                        'likes': 727,
#                        'quotes': 4,
#                        'retweets': 228},
#              'text': 'केंद्र की @BJP4India सरकार द्वारा लागू CAA Rules के '
#                      'ताल्लुक़ से AIMIM अध्यक्ष बैरिस्टर @asadowaisi की प्रेस '
#                      'कांफ्रेंस   #AIMIM #AsaduddinOwaisi #CAA #NPR #NRC '
#                      '#PressConference #Muslims #Dalits #Tribals '
#                      '#CitizenshipAmendmentBill #India #Bharat',
# ...

# %%
tweets.keys()
# Out:
# dict_keys(['tweets', 'threads'])

# %%
tweets['tweets'][0]
# Out:
# {'link': 'https://twitter.com/aimim_national/status/1767523795814985760#m',
#  'text': 'केंद्र की @BJP4India सरकार द्वारा लागू CAA Rules के ताल्लुक़ से AIMIM अध्यक्ष बैरिस्टर @asadowaisi की प्रेस कांफ्रेंस   #AIMIM #AsaduddinOwaisi #CAA #NPR #NRC #PressConference #Muslims #Dalits #Tribals #CitizenshipAmendmentBill #India #Bharat',
#  'user': {'name': 'AIMIM',
#   'username': '@aimim_national',
#   'profile_id': '1416738257920872449',
#   'avatar': 'https://pbs.twimg.com/profile_images/1416738257920872449/liUtp-Xk_bigger.jpg'},
#  'date': 'Mar 12, 2024 · 12:11 PM UTC',
#  'is-retweet': False,
#  'is-pinned': True,
#  'external-link': '',
#  'replying-to': [],
#  'quoted-post': {},
#  'stats': {'comments': 30, 'retweets': 228, 'quotes': 4, 'likes': 727},
#  'pictures': [],
#  'videos': ['https://video.twimg.com/amplify_video/1767512415246417920/vid/avc1/1280x720/yKTDRimKD-bmbcsy.mp4?tag=14'],
#  'gifs': []}

# %%
mim = scraper.get_profile_info(username="@aimim_national")
# Out:
# 04-Apr-24 14:50:32 - No instance specified, using random instance https://nitter.privacydev.net

# %%
pprint(mim)
# Out:
# {'bio': 'Official twitter account of All India Majlis-e-Ittehadul Muslimeen.',
#  'id': '185563034',
#  'image': 'https://pbs.twimg.com/profile_images/1416738257920872449/liUtp-Xk_400x400.jpg',
#  'joined': '8:39 AM - 1 Sep 2010',
#  'location': '',
#  'name': 'AIMIM',
#  'stats': {'followers': 1068637,
#            'following': 61,
#            'likes': 11848,
#            'media': 0,
#            'tweets': 20061},
#  'username': '@aimim_national',
#  'website': ''}

# %%
data = {
    'link':[],
    'text':[],
    'user':[],
    'date':[],
    'likes':[],
    'quotes':[],
    'retweets':[],
    'comments':[]
}
for tweet in tweets['tweets']:
    data['link'].append(tweet['link'])
    data['text'].append(tweet['text'])
    data['date'].append(tweet['date'])
    data['user'].append(tweet['user']['name'])
    data['likes'].append(tweet['stats']['likes'])
    data['quotes'].append(tweet['stats']['quotes'])
    data['retweets'].append(tweet['stats']['retweets'])
    data['comments'].append(tweet['stats']['comments'])

# %%
data
# Out:
# {'link': ['https://twitter.com/aimim_national/status/1767523795814985760#m',
#   'https://twitter.com/aimim_national/status/1775788118576427486#m',
#   'https://twitter.com/aimim_national/status/1775565504645861503#m',
#   'https://twitter.com/AIMIM_Bihar1/status/1775553311594176929#m',
#   'https://twitter.com/aimim_national/status/1775545107015766431#m',
#   'https://twitter.com/aimim_national/status/1775545102968193239#m',
#   'https://twitter.com/MainMediaHun/status/1775443474088685711#m',
#   'https://twitter.com/Md_MajidHussain/status/1775502596486336795#m',
#   'https://twitter.com/AIMIM_Bihar1/status/1769740628924244412#m',
#   'https://twitter.com/Akhtaruliman5/status/1772236238462030028#m',
#   'https://twitter.com/AIMIM_Bihar1/status/1775124729088623041#m',
#   'https://twitter.com/AIMIM_Bihar1/status/1775502956198064408#m',
#   'https://twitter.com/MuslimSpaces/status/1775177810413600806#m',
#   'https://twitter.com/YouthSartajAlam/status/1775413270234730508#m',
# ...

# %%
import pandas as pd
df = pd.DataFrame(data)
df.head()
# Out:
#                                                 link  \
# 0  https://twitter.com/aimim_national/status/1767...
# 1  https://twitter.com/aimim_national/status/1775...
# 2  https://twitter.com/aimim_national/status/1775...
# 3  https://twitter.com/AIMIM_Bihar1/status/177555...
# 4  https://twitter.com/aimim_national/status/1775...
#
#                                                 text                  user  \
# 0  केंद्र की @BJP4India सरकार द्वारा लागू CAA Rul...                 AIMIM
# 1  Ye waqt ittehad paida karne ka hai. Aap sab ap...                 AIMIM
# 2  Barrister @asadowaisi ne Bahadurpura MLA @Mohd...                 AIMIM
# 3  किशनगंज लोकसभा निर्वाचन क्षेत्र से AIMIM प्रत्...  AIMIM Bihar Official
# 4                                                                    AIMIM
#
#                           date  likes  quotes  retweets  comments
# 0  Mar 12, 2024 · 12:11 PM UTC    727       4       228        30
# ...

# %%
df.to_csv("final1mim.csv")
