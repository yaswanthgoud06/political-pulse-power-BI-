# %%
from ntscraper import Nitter

# %%
scraper = Nitter(log_level = 1,skip_instance_check= False)
# Out:
# Testing instances: 100%|███████████████████████████████████████████████████████████████| 77/77 [02:21<00:00,  1.84s/it]

# %%
tweets = scraper.get_tweets('BJP4India',mode= 'user', number=10000)
# Out:
# 04-Apr-24 14:36:18 - No instance specified, using random instance https://nitter.privacydev.net
# 04-Apr-24 14:36:24 - Current stats for BJP4India: 20 tweets, 0 threads...
# 04-Apr-24 14:36:28 - Current stats for BJP4India: 40 tweets, 0 threads...
# 04-Apr-24 14:36:32 - Current stats for BJP4India: 60 tweets, 0 threads...
# 04-Apr-24 14:36:36 - Current stats for BJP4India: 80 tweets, 0 threads...
# 04-Apr-24 14:36:40 - Current stats for BJP4India: 100 tweets, 0 threads...
# 04-Apr-24 14:36:44 - Current stats for BJP4India: 120 tweets, 0 threads...
# 04-Apr-24 14:36:47 - Current stats for BJP4India: 140 tweets, 0 threads...
# 04-Apr-24 14:36:52 - Current stats for BJP4India: 160 tweets, 0 threads...
# 04-Apr-24 14:36:56 - Current stats for BJP4India: 180 tweets, 0 threads...
# 04-Apr-24 14:36:59 - Current stats for BJP4India: 200 tweets, 0 threads...
# 04-Apr-24 14:37:04 - Current stats for BJP4India: 220 tweets, 0 threads...
# ...

# %%
from pprint import pprint

# %%
pprint(tweets)
# Out:
# {'threads': [],
#  'tweets': [{'date': 'Apr 4, 2024 · 5:10 AM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': False,
#              'is-retweet': False,
#              'link': 'https://twitter.com/BJP4India/status/1775752800288280728#m',
#              'pictures': ['https://pbs.twimg.com/media/GKS9utuX0AA8UAU.jpg'],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 64,
#                        'likes': 469,
#                        'quotes': 18,
#                        'retweets': 164},
#              'text': "Why NaMo Again? 🪷  To up Bharat's Game! 🇮🇳",
#              'user': {'avatar': 'https://pbs.twimg.com/profile_images/1700102447061245952/OyNepKMe_bigger.jpg',
#                       'name': 'BJP',
#                       'profile_id': '1700102447061245952',
#                       'username': '@BJP4India'},
#              'videos': []},
# ...

# %%
tweets['tweets'][0]
# Out:
# {'link': 'https://twitter.com/BJP4India/status/1775752800288280728#m',
#  'text': "Why NaMo Again? 🪷  To up Bharat's Game! 🇮🇳",
#  'user': {'name': 'BJP',
#   'username': '@BJP4India',
#   'profile_id': '1700102447061245952',
#   'avatar': 'https://pbs.twimg.com/profile_images/1700102447061245952/OyNepKMe_bigger.jpg'},
#  'date': 'Apr 4, 2024 · 5:10 AM UTC',
#  'is-retweet': False,
#  'is-pinned': False,
#  'external-link': '',
#  'replying-to': [],
#  'quoted-post': {},
#  'stats': {'comments': 64, 'retweets': 164, 'quotes': 18, 'likes': 469},
#  'pictures': ['https://pbs.twimg.com/media/GKS9utuX0AA8UAU.jpg'],
#  'videos': [],
#  'gifs': []}

# %%
bjp = scraper.get_profile_info(username="@BJP4India")
# Out:
# 04-Apr-24 14:37:47 - No instance specified, using random instance https://nitter.privacydev.net

# %%
pprint(bjp)
# Out:
# {'bio': "Welcome to official account of the world's largest Political Party of "
#         "the world's largest Democracy- BHARATIYA JANATA PARTY, भारतीय जनता "
#         'पार्टी.',
#  'id': '207809313',
#  'image': 'https://pbs.twimg.com/profile_images/1700102447061245952/OyNepKMe_400x400.jpg',
#  'joined': '2:19 AM - 26 Oct 2010',
#  'location': '6-A, Deen Dayal Upadhyay Marg,',
#  'name': 'BJP',
#  'stats': {'followers': 21742797,
#            'following': 3,
#            'likes': 0,
#            'media': 0,
#            'tweets': 260587},
#  'username': '@BJP4India',
#  'website': 'http://www.bjp.org'}

# %%
data = {
    'link':[],
    'text':[],
    'user':[],
    'date':[],
    'likes':[],
    'quotes':[],
    'retweets':[],
    'comments':[],
}
for tweet in tweets['tweets']:
    data['link'].append(tweet['link'])
    data['text'].append(tweet['text'])
    data['user'].append(tweet['user']['name'])
    data['date'].append(tweet['date'])
    data['likes'].append(tweet['stats']['likes'])
    data['quotes'].append(tweet['stats']['quotes'])
    data['retweets'].append(tweet['stats']['retweets'])
    data['comments'].append(tweet['stats']['comments'])

# %%
data
# Out:
# {'link': ['https://twitter.com/BJP4India/status/1775752800288280728#m',
#   'https://twitter.com/BJP4India/status/1775748510790320362#m',
#   'https://twitter.com/BJP4India/status/1775727492101243311#m',
#   'https://twitter.com/BJP4India/status/1775712392632062334#m',
#   'https://twitter.com/BJP4India/status/1775553047906669020#m',
#   'https://twitter.com/BJP4India/status/1775544786998776191#m',
#   'https://twitter.com/BJP4India/status/1775539827263279555#m',
#   'https://twitter.com/BJP4India/status/1775526266386497556#m',
#   'https://twitter.com/BJP4India/status/1775511622255010116#m',
#   'https://twitter.com/BJP4India/status/1775511303940931679#m',
#   'https://twitter.com/BJP4India/status/1775506826705977573#m',
#   'https://twitter.com/BJP4India/status/1775504605700333895#m',
#   'https://twitter.com/BJP4India/status/1775499923623997721#m',
#   'https://twitter.com/BJP4India/status/1775499339395174510#m',
#   'https://twitter.com/BJP4India/status/1775498674551873698#m',
# ...

# %%
import pandas as pd
df = pd.DataFrame(data)
df.head()
# Out:
#                                                 link  \
# 0  https://twitter.com/BJP4India/status/177575280...
# 1  https://twitter.com/BJP4India/status/177574851...
# 2  https://twitter.com/BJP4India/status/177572749...
# 3  https://twitter.com/BJP4India/status/177571239...
# 4  https://twitter.com/BJP4India/status/177555304...
#
#                                                 text user  \
# 0         Why NaMo Again? 🪷  To up Bharat's Game! 🇮🇳  BJP
# 1  BJP National Spokesperson Dr. @SudhanshuTrived...  BJP
# 2  देश का तीव्र गति से विकास, गरीबों और वंचितों क...  BJP
# 3  इसलिए मोदी जरूरी है...  अनुच्छेद 370 हटाकर जम्...  BJP
# 4  मोदी जी जैसा प्रधानमंत्री दुर्लभ ही मिलता है! ...  BJP
#
#                         date  likes  quotes  retweets  comments
# 0  Apr 4, 2024 · 5:10 AM UTC    469      18       164        64
# 1  Apr 4, 2024 · 4:53 AM UTC    435       6       153        41
# 2  Apr 4, 2024 · 3:30 AM UTC    955      11       381        84
# ...

# %%
df.to_csv("final1bjp.csv")
